# %%
import torch
import torch.optim as optim
import numpy as np

# %%
# Random seed to make results deterministic and reproducible
torch.manual_seed(0)

# %%
sentence = ("if you want to build a ship, don't drum up people together to "
            "collect wood and don't assign them tasks and work, but rather "
            "teach them to long for the endless immensity of the sea.")

# %%
# make dictionary
char_set = list(set(sentence))
char_dic = {c: i for i, c in enumerate(char_set)}

# %%
# hyper parameters
dic_size = len(char_dic)
hidden_size = len(char_dic)
sequence_length = 10  # Any arbitrary number
learning_rate = 0.1

# %%
# data setting
x_data = []
y_data = []

for i in range(0, len(sentence) - sequence_length):
    x_str = sentence[i:i + sequence_length]
    y_str = sentence[i + 1: i + sequence_length + 1]
    print(i, x_str, '->', y_str)

    x_data.append([char_dic[c] for c in x_str])  # x str to index
    y_data.append([char_dic[c] for c in y_str])  # y str to index

x_one_hot = [np.eye(dic_size)[x] for x in x_data]
# Out:
# 0 if you wan -> f you want
# 1 f you want ->  you want
# 2  you want  -> you want t
# 3 you want t -> ou want to
# 4 ou want to -> u want to
# 5 u want to  ->  want to b
# 6  want to b -> want to bu
# 7 want to bu -> ant to bui
# 8 ant to bui -> nt to buil
# 9 nt to buil -> t to build
# 10 t to build ->  to build
# 11  to build  -> to build a
# 12 to build a -> o build a
# 13 o build a  ->  build a s
# 14  build a s -> build a sh
# 15 build a sh -> uild a shi
# 16 uild a shi -> ild a ship
# 17 ild a ship -> ld a ship,
# 18 ld a ship, -> d a ship,
# 19 d a ship,  ->  a ship, d
# 20  a ship, d -> a ship, do
# 21 a ship, do ->  ship, don
# 22  ship, don -> ship, don'
# 23 ship, don' -> hip, don't
# 24 hip, don't -> ip, don't
# 25 ip, don't  -> p, don't d
# 26 p, don't d -> , don't dr
# 27 , don't dr ->  don't dru
# 28  don't dru -> don't drum
# 29 don't drum -> on't drum
# 30 on't drum  -> n't drum u
# 31 n't drum u -> 't drum up
# 32 't drum up -> t drum up
# 33 t drum up  ->  drum up p
# 34  drum up p -> drum up pe
# 35 drum up pe -> rum up peo
# 36 rum up peo -> um up peop
# 37 um up peop -> m up peopl
# 38 m up peopl ->  up people
# 39  up people -> up people
# 40 up people  -> p people t
# 41 p people t ->  people to
# 42  people to -> people tog
# 43 people tog -> eople toge
# 44 eople toge -> ople toget
# 45 ople toget -> ple togeth
# 46 ple togeth -> le togethe
# 47 le togethe -> e together
# 48 e together ->  together
# 49  together  -> together t
# 50 together t -> ogether to
# 51 ogether to -> gether to
# 52 gether to  -> ether to c
# 53 ether to c -> ther to co
# 54 ther to co -> her to col
# 55 her to col -> er to coll
# 56 er to coll -> r to colle
# 57 r to colle ->  to collec
# 58  to collec -> to collect
# 59 to collect -> o collect
# 60 o collect  ->  collect w
# 61  collect w -> collect wo
# 62 collect wo -> ollect woo
# 63 ollect woo -> llect wood
# 64 llect wood -> lect wood
# 65 lect wood  -> ect wood a
# 66 ect wood a -> ct wood an
# 67 ct wood an -> t wood and
# 68 t wood and ->  wood and
# 69  wood and  -> wood and d
# 70 wood and d -> ood and do
# 71 ood and do -> od and don
# 72 od and don -> d and don'
# 73 d and don' ->  and don't
# 74  and don't -> and don't
# 75 and don't  -> nd don't a
# 76 nd don't a -> d don't as
# 77 d don't as ->  don't ass
# 78  don't ass -> don't assi
# 79 don't assi -> on't assig
# 80 on't assig -> n't assign
# 81 n't assign -> 't assign
# 82 't assign  -> t assign t
# 83 t assign t ->  assign th
# 84  assign th -> assign the
# 85 assign the -> ssign them
# 86 ssign them -> sign them
# 87 sign them  -> ign them t
# 88 ign them t -> gn them ta
# 89 gn them ta -> n them tas
# 90 n them tas ->  them task
# 91  them task -> them tasks
# 92 them tasks -> hem tasks
# 93 hem tasks  -> em tasks a
# 94 em tasks a -> m tasks an
# 95 m tasks an ->  tasks and
# 96  tasks and -> tasks and
# 97 tasks and  -> asks and w
# 98 asks and w -> sks and wo
# 99 sks and wo -> ks and wor
# 100 ks and wor -> s and work
# 101 s and work ->  and work,
# 102  and work, -> and work,
# 103 and work,  -> nd work, b
# 104 nd work, b -> d work, bu
# 105 d work, bu ->  work, but
# 106  work, but -> work, but
# 107 work, but  -> ork, but r
# 108 ork, but r -> rk, but ra
# 109 rk, but ra -> k, but rat
# 110 k, but rat -> , but rath
# 111 , but rath ->  but rathe
# 112  but rathe -> but rather
# 113 but rather -> ut rather
# 114 ut rather  -> t rather t
# 115 t rather t ->  rather te
# 116  rather te -> rather tea
# 117 rather tea -> ather teac
# 118 ather teac -> ther teach
# 119 ther teach -> her teach
# 120 her teach  -> er teach t
# 121 er teach t -> r teach th
# 122 r teach th ->  teach the
# 123  teach the -> teach them
# 124 teach them -> each them
# 125 each them  -> ach them t
# 126 ach them t -> ch them to
# 127 ch them to -> h them to
# 128 h them to  ->  them to l
# 129  them to l -> them to lo
# 130 them to lo -> hem to lon
# 131 hem to lon -> em to long
# 132 em to long -> m to long
# 133 m to long  ->  to long f
# 134  to long f -> to long fo
# 135 to long fo -> o long for
# 136 o long for ->  long for
# 137  long for  -> long for t
# 138 long for t -> ong for th
# 139 ong for th -> ng for the
# 140 ng for the -> g for the
# 141 g for the  ->  for the e
# 142  for the e -> for the en
# 143 for the en -> or the end
# 144 or the end -> r the endl
# 145 r the endl ->  the endle
# 146  the endle -> the endles
# 147 the endles -> he endless
# 148 he endless -> e endless
# 149 e endless  ->  endless i
# 150  endless i -> endless im
# 151 endless im -> ndless imm
# 152 ndless imm -> dless imme
# 153 dless imme -> less immen
# 154 less immen -> ess immens
# 155 ess immens -> ss immensi
# 156 ss immensi -> s immensit
# 157 s immensit ->  immensity
# 158  immensity -> immensity
# 159 immensity  -> mmensity o
# 160 mmensity o -> mensity of
# 161 mensity of -> ensity of
# 162 ensity of  -> nsity of t
# 163 nsity of t -> sity of th
# 164 sity of th -> ity of the
# 165 ity of the -> ty of the
# 166 ty of the  -> y of the s
# 167 y of the s ->  of the se
# 168  of the se -> of the sea
# 169 of the sea -> f the sea.

# %%
# transform as torch tensor variable
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)

# %%
# declare RNN + FC
class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, layers):
        super(Net, self).__init__()
        self.rnn = torch.nn.RNN(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        self.fc = torch.nn.Linear(hidden_dim, hidden_dim, bias=True)

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x)
        return x

# %%
net = Net(dic_size, hidden_size, 2)

# %%
# loss & optimizer setting
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), learning_rate)

# %%
# start training
for i in range(100):
    optimizer.zero_grad()
    outputs = net(X)
    loss = criterion(outputs.view(-1, dic_size), Y.view(-1))
    loss.backward()
    optimizer.step()

    results = outputs.argmax(dim=2)
    predict_str = ""
    for j, result in enumerate(results):
        # print(i, j, ''.join([char_set[t] for t in result]), loss.item())
        if j == 0:
            predict_str += ''.join([char_set[t] for t in result])
        else:
            predict_str += char_set[result[-1]]

    print(predict_str)
# Out:
# cannc.ccnncnnnannaaac.ncaacanncncnncnnacnnbbbnbb.ccnccna.ncnnann.aannncnnbn.ncnncncnnancacacnbaacnbacccancncnacannncnaan..acnbaannnb.acnnananccccacnb.cnnc.aacccaaancacaacannb.ccna
#
# albh lbo lbbbbbbbb'bbbbbbbblbbblbbbbbbbbslbbbblbbbbblbbbbbbblbbblbbbbbbhlbbblbbbblbbbbbbbh lbtlbbbbbbbbbblbbh'bbbbbhbbsa'belbbbbblbblbbblbbblbbbblbbeabbblbbbbbbolbbllbtlbblbhabbsl
# o     o    o o o o   o o o o o   o o o o    o     o             o     o   o   o    o   o o    o o o             o  o   o o o   o o    t   o        o   o       o                o o
# t t eledtdttttlededttttt tdtttt   tdtdttttttttlelt tlededttttt  t    tdtdedtt t tdtdedtdtdtltd  td lt tdtdtdtltledtdtdtde  dtdtdttt ltt t eltd et t  dedtledtltdt  t tdtdt tdedtttt
# teamelttmh nnhptt e tnt n h mn  hemn rhtmh he meemh nhn n t tpteme   mhenht h mn  hnmhenmh mhe  n   hemhe rhe h mhemt nnen tm  heahemhtmtptemtthe te mhn nhn h hn hn mhnmhemhemhn h
# totm lteit t  ite tetot  it a  ptest s t titeiteito s e t totpteiteteiteittpteto ptestess  to f t  itefte to at ttest so t t titeiteist tpsepte tite t o    itito  e t ts eaoepteps
# tos  c o t t t toto t t   t   t t t  s t   to    to   o   t t     i o to  o   t t t t o to  o s t t t t   t t t t t t to   t   t t    oot   c t t to  to  o   tto to to to t  sto
# t t      d t    d   t t   t       t              t        t       i           t     t   t       t     t   t   t t t t to c t   t t            i t t   to             t  t  t   t
# t t  '   i to b iwe t t ek  t  m  t  k i  k  i eit      i to k i ei  k    to  t  k it   t  t  i to k  t   to ct to  t to i t  k  i ec to k ik i d t  ct              to t  toect  t
# t to mt  t th l ntd t t ilt th  t th m to t      t   t    th l   ei  to   t   th  t to  th t  t th kt th  th kt thi t th k th  t toek th l  k tht th kth      to  t  th t  th kt
# t to mtn g toel nlr t t ilt toi t to m to to g   to mt  g toelonme l ton  tnt to mt t n toitoeg to kt t i to ct toi t toem to gtetoem toeloec aoi themth    m to  n  th to toemt  m
# totosmtrnt toelor r tot ilt todmt todm to to r e tosmt em toelon e o ton ltnt todmt t n toiloem toemt tor tod t tot t toem to moetoem toeloem tot toemto  e m to  r  to to toemto p
# lotosmtant tosluild t t elt todmt t  m to to  le tos t em toslonle   tonm tnt tosmt tmo tosloem tosmt t d ton t tot t toem tosmo toem toslonl tod toemtns e m tln n  to po toemt s
# loaosmtnnt tosluild t t epo ton't t  m tm tonnle tos t em toslunlem  ton  tnt ton't tmo tosloem to mt t t tonct tot t toem to co toem toslunl tod toemlns e m tlo n  to po toe t n
# loaos'tnnt toecuild t t ep, ton't to m tm tonnle tos t es to cunles  tons ant ton't tme to loem toe s tnd donct tot tctoem to so toem toecuic dod toemtns e i tao d  to do t e t
# coaon'tnnt th cuiln tathept ton't aoe' dm donnle tos thes to curlest tonslant ton't aneitostoe' toekt tnd donct tnt datoe' to dt the' toscunc aod the'tnn e d tao ns th tt the to l
# coah 'tant th cuild t t e t ton't ao ' tm po  le to  them th curle t tonm and aon't ame  h toeh th ks tod tonk, tnt tatheh th st theh to cuig aod thehtos e i tah rs th pd t e th
# loaoamtant tonbodld tathilt ton't aoam tt tonnle tos toet to lortert tonntant ton't ant tontoem ton t tod tonct tat tatoer to tt them tonlonc aod toemtanle t tao ot th ttntoemtonr
# lotlemtand wh cuild t t i t aonlt am ' dm ph rle th  ther th lerle t tonr dod tonlt amii h t e  the i toi tonk, aud t the  th gtithem th cerg aod the woile i wah r  wh pn the wh
# loslectnnd to cuild t t i t aonlt ao ' dm ton le th kther th lerlert tonr dod ton't an i e them toeks tod tonkt aud tnther to ctithem to cerg aod themtnile i gmo n  wh mn themth l
# cosluctnnd to ludld tnt ip, don't ao m dm ponnle to ktoem to lerlert tonr und ton't an igo them toskt tnd tonk, put tnther to ceitoem to lerg aod toemunsle d tmo ns th nn toemun g
# cothumtand tosbudld tnt ip, ton't toum dm ,eonle tos them tosberlert tonrltnd ton't ant gn them toskt tnd tonk, pud tathem to m,ethem tosberg aod themunsle d tp, nd gm pd themuns
# cothnmtant toscudld t t ip, aon't aoum am p onle ths them to corlert tonr tnd aon't ant gn them tosks tnd tonk, aud aathem to chethem tosce g aod themunsle g tp, ns tm pn themuen
# cnalectant ao cudld a t ild aon't aoum am p onle th  toer th corlect tont and aon't ansign them tosks tnd aonk, aud aathem to chethem to leng aon themansle g tpm n ith pn themaet
# cnshectant to cudld t thil, ton't amur a, peo le th  ther th corlect tonc and aon't ansign them tosks tnd tonk, put aathem to chethem to leng aon themwnele s gpm n ith pn themaht
# losoe'tant ao cudld t thil, ton't amur dm oeonle to  ther th conlert tont and aon't ansite them tosks tnd tonk, put aathem to chether to long don themwnsle d ipm oeith on themwht
# loloe'want ao budld d thip, ton't amur dm peonle to  ther th bonlect tont and don't ansign ther tosks tnd tonk, but dather to ch ther to long don themwndle d ipm nsito on the wht
# loloe'want wo budld d dhip, don't amur dm peonle th  ther th bo lect wond and don't ansign them to ks tnd donk, put dathem to ch them to bong don themwnd e d gpm nsiwo on thi wht
# lollemwant wo budld d dhip, don't amum dm peoale th  them to bo lect tond and don't ansign them to ks tnd aonk, dut aathem to ch them to long dod themwndle d gpmeosigo of thi uht
# loslemwant to build t dhip, don't arum dm peonle thg ther th bo lect tond and aon't ansign them tosks tnd tonk, dut aather to ch them to long dor themwndlend gpmensigh of the uho
# lnlhemwant to build t dhip, don't trum dm peonle thg ther th bo lect tond and ton't tnsign them tosks tnd tonk, dut aather to ch them to long dor themwndlers gpmensigy of themueoc
# loahumwant to build t ship, don't arum dm peonle tog ther th bo lect tond and aon't ansign them tosks tnd tonk, dut dather to ch them to long dor themwndlecs gpyensigy pf themae c
# aoaoumwant ao build t thip, don't arum dm peonle tog them to bo lect tond and aon't ansign them tosks and aonk, dut dather to ch them to long dor themwndlecs immensigy of themwesc
# aoaoumwant ao luild t thip, don't aoum dm peo le tog them to bo lect tond and don't ansign them tosks and aonk, dut dather to ch them to long dor themwndless immensigy of themwesc
# aoaou want to luild t thip, don't aoum dm peonle tog them to co lect tond and don't ansign them tosks tnd donk, aut dather to ch them to long dor themwndle s immensity of themwesc
# lnoou want to build t thip, don't arum dm peonle tog ther to bo lect tord and don't ansign them tosks tnd donk, but dather th ch them to long dor themendle s immensity of themeeoc
# lnaou want to build t thip, don't arum dm peonle tog ther to bo lect word and don't ansign them tosks tnd donk, but dather to ch them to long dor themendless immensity of themeeoc
# lnaou want to build t ship, don't arum dm peonle tog ther to bo lect word and don't ansign them tosks tnd donk, but dather to ch them to long for themendle s immensity of themeeoc
# lnaou want to build t ship, don't arum dm peonle together to co lect tood and don't ansign them tosks tnd dork, but dather toach them to long for themendless immensity of themeeoc
# lnaou want to cuild t ship, don't arum um people togethem to collect tood and don't assign them tosks tnd donk, but dather toach them to long for themwndle s immensity of themtetc
# loaou want to build t thip, don't arum um peonle together to bollect tood and don't assign toem tosks tnd aook, but dather toach them toalong for themendless immensity of themeeoc
# tyaou want to build t ship, don't trum um people togethem to collect tood and don't tssign them tosks wnd donk, but dather th ch the  to long for the endle s immensity of the ee c
# tyaou want to build t ship, don't arum dm people together to collect tood and don't assign them tosks and donk, but bather thach them to long for themendless immensity of themee c
# moaou want to build t ship, don't arum um people together to bollect wood and don't assign them tosks and dook, but father toach them to long for themendless immensity of themeeac
# tyaou want to cuild a ship, don't arum um people together togcollect wood ant don't ansign them tosks and donk, but father toach them to long for the endless immensity of the eeac
# tyeou want to cuild a ship, don't arum um people together to collect aood and don't assign them tosks and donk, but father thach them to long for themendless immensity of themeeac
# myeou want to build a ship, don't arum um people together to lollect aood and don't assign them tosks and dork, but father toach them to long for themendless immensity of themeeac
# bysou want to build a ship, don't drum um people together to bollect wood and don't assign them tosks and dook, but father toach them to long for the endless immensigy of the eeac
# bosou want to build a thip, don't wrum um people together to bollect wood and don't assign them tosks and wook, but bather thach them to long for themendless immensity of themeeac
# loeou want to build a ship, don't arum um people togethet to bollect wood and don't assign them tosks and dork, but father thach them to long for the endless immensity of the eeac
# byeou want to build a ship, don't drum um people together to bollect wood and don't dssign the  tosks and dork, but father thach them to long for the endless immensity of the eeac
# gyeou want to build a ship, don't drum um people together to collect wood and don't dssign them tosks and dork, but rather toach them to long for the endless immensity of the eeac
# gyeou want to build a ship, don't drum um people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the eeac
# gyeou want to cuild a ship, don't drum um people together to collect wood and don't wssign them tosks and work, but rather toach them to long for the endless immensity of the eeac
# gyoou want to build a ship, don't drum um people together to collect wood and don't assign the  tosks and work, but rather toach them to long for the endless immensity of the eeac
# gyoou want to build a ship, don't drum um people together to bollect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the eeac
# gyoou want to build a ship, don't drum up people together to collect wood and don't wssign them tosks and dork, but rather thach them to long for the endless immensity of the ee c
# lyoou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the eeac
# lpoou want to cuild a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the eeac
# lpoou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the eeac
# lpoou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather thach them to long for the endless immensity of the seac
# lmoou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather thach them to long for the endless immensity of the seac
# lpoou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the seac
# lpoou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the eeac
# lpyou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the teac
# lyoou want to build a ship, don't frum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the eea
# gysou want to cuild a ship, don't drum up people togethem to collect wood and don't dssign them tosks and work, but rather thach them to long for the endless immensity of the setc
# lyoou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather toach them toalong for the ondless immensity of the seac
# ppyou wand to build a ship, don't drum up people together to collect word and don't dssign them tosks and work, but rather thach them to cong for the sndless immensity of the seac
# looou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and wook, but rather toach them to long for the endless immensity of the eeac
# loyou want to luild a ship, don't drum up people together to lollect wood and don't ansign them tosks and aork, but rather toach them to long for themendless immensity of themeeac
# fpyou want to cuild a ship, don't drum up people to ether to collect wood and don't assign them to ks and dork, but rather toach them to cong for the endless immensity of the eeac
# fpyou want to cuild a ship, don't dr m up people to ether to collect wood and don't assign them to ks and wook, but rather toach them to conghfor the sndless immensity of the seac
# goaou want to build a ship, don't arum up people together to collect wood and don't assign them tosks and dork, but rather toach them to bong for the endless immensity of the eeas
# goyou want to build a ship, don't drum up people together to bollect wood and don't assign them tosks and dork, but rather toach them to bong for the endless immensity of the eeas
# fyeou want to build a ship, don't drum up people together to bollect wood and don't assign them tosks and dork, but rather toach them to long for the endless imm nsity of the eeas
# fyuou want to build a ship, don't arum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the eeac
# fpuou want to build a ship, don't arum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the eeac
# ppeou want to build a ship, don't arum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the seac
# pmeou want to build a ship, don't drum up people togeaher to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the serc
# tmemu want to cuild a ship, don't arum up people together to collect wood and don't assign them tosks and dor , but rather thach them to long for the sndless immensity of the seac
# tmeou want to build a ship, don't arum up people together to bollect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the eeac
# tmeou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and dork, but rather toach them to long for the sndless immensity of the sea
# pmeou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the sndless immensity of the seac
# f eou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the seac
# f eou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the seac
# t eou want to build a ship, don't drum up people together to collect wood and don't dssign them tosks and dork, but rather toach them to long for the endless immensity of the seac
# t eou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the seas
# t eou want to build a ship, don't drum up people together to collect wood and don't assign them tosks and dork, but rather teach them to long for the endless immensity of the seas
# m you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the seac
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the seac
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the seac
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the seac
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the seac
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the seac
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather toach them to long for the endless immensity of the seac
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the seac
# m you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the seas
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tosks and work, but rather teach them to long for the endless immensity of the seac
